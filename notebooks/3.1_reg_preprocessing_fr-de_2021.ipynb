# %%
import sys
sys.path.insert(0, '../src/')

import pandas as pd
import kaggle
import auto_co2 as co2
import importlib
importlib.reload(co2)
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /home/mln/.kaggle/kaggle.json'
# 2024-01-15 19:53:54.489145: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-15 19:53:54.505463: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <module 'auto_co2' from '/home/mln/GIT/car-co2-prediction_pre-release/notebooks/../src/auto_co2/__init__.py'>

# %%
df = co2.data.load_co2_data()

# %%
# Inspection des données
co2.styles.displayer(df, title='APERCU DU JEU DE DONNEES: FR/ALL 2021', save=True)
co2.styles.display_info(df, title='DONNEES BRUTES: FR/ALL 2021', save=True) 
co2.styles.display_na(df, title='PART DE VALEURS MANQUANTES DANS LE JEU DE DONNEES: FR/ALL 2021', save=True)   

# Nettoyage des données
df = co2.data.ml_preprocess(df,
                               #countries=['FR', 'DE'],
                               rem_axlewidth=True,
                               rem_fuel_consumption=True,
                               rem_engine_capacity=True)


# Inspection des features
co2.styles.display_info(df, title='DONNEES NETTOYEES: FR/ALL 2021', save=True) 
co2.styles.display_describe(df, title='STATISTIQUES DESCRIPTIVES: FR/ALL 2021', save=True)

co2.viz.plot_correlation_heatmap(df, save=True, interactive=False, title=': FR/ALL 2021')
co2.viz.plot_feature_distributions(df, interactive=False, save=True, title=': FR/ALL 2021')
co2.viz.plot_qqplots(df, interactive=False, save=True, title=': FR/ALL 2021')

# One-hot encoding des variables catégorielles
df = co2.data.dummify_all_categoricals(df, should_discretize_electricrange=False)
df['ElectricRange'] = df['ElectricRange'].fillna(0)

# Sauvegarde du jeu de données prêt à l'emploi pour la régression
co2.data.save_processed_data(df, classification=False, pickle=False)
# Out:
# <style type="text/css">
# #T_12fc0 th {
#   background-color: steelblue;
#   color: white;
# }
# #T_12fc0 tr:nth-of-type(odd) {
#   background-color: aliceblue;
# }
# #T_12fc0 tr:nth-of-type(even) {
#   background-color: white;
# }
# </style>
# <table id="T_12fc0">
#   <caption><h2>APERCU DU JEU DE DONNEES: FR/ALL 2021</h2></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12fc0_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_12fc0_level0_col1" class="col_heading level0 col1" >Country</th>
#       <th id="T_12fc0_level0_col2" class="col_heading level0 col2" >VFN</th>
#       <th id="T_12fc0_level0_col3" class="col_heading level0 col3" >Mp</th>
#       <th id="T_12fc0_level0_col4" class="col_heading level0 col4" >Mh</th>
#       <th id="T_12fc0_level0_col5" class="col_heading level0 col5" >Man</th>
#       <th id="T_12fc0_level0_col6" class="col_heading level0 col6" >MMS</th>
#       <th id="T_12fc0_level0_col7" class="col_heading level0 col7" >Tan</th>
#       <th id="T_12fc0_level0_col8" class="col_heading level0 col8" >T</th>
#       <th id="T_12fc0_level0_col9" class="col_heading level0 col9" >Va</th>
#       <th id="T_12fc0_level0_col10" class="col_heading level0 col10" >Ve</th>
#       <th id="T_12fc0_level0_col11" class="col_heading level0 col11" >Mk</th>
#       <th id="T_12fc0_level0_col12" class="col_heading level0 col12" >Cn</th>
#       <th id="T_12fc0_level0_col13" class="col_heading level0 col13" >Ct</th>
#       <th id="T_12fc0_level0_col14" class="col_heading level0 col14" >Cr</th>
#       <th id="T_12fc0_level0_col15" class="col_heading level0 col15" >r</th>
#       <th id="T_12fc0_level0_col16" class="col_heading level0 col16" >m (kg)</th>
#       <th id="T_12fc0_level0_col17" class="col_heading level0 col17" >Mt</th>
#       <th id="T_12fc0_level0_col18" class="col_heading level0 col18" >Enedc (g/km)</th>
#       <th id="T_12fc0_level0_col19" class="col_heading level0 col19" >Ewltp (g/km)</th>
#       <th id="T_12fc0_level0_col20" class="col_heading level0 col20" >W (mm)</th>
#       <th id="T_12fc0_level0_col21" class="col_heading level0 col21" >At1 (mm)</th>
#       <th id="T_12fc0_level0_col22" class="col_heading level0 col22" >At2 (mm)</th>
#       <th id="T_12fc0_level0_col23" class="col_heading level0 col23" >Ft</th>
#       <th id="T_12fc0_level0_col24" class="col_heading level0 col24" >Fm</th>
#       <th id="T_12fc0_level0_col25" class="col_heading level0 col25" >ec (cm3)</th>
#       <th id="T_12fc0_level0_col26" class="col_heading level0 col26" >ep (KW)</th>
#       <th id="T_12fc0_level0_col27" class="col_heading level0 col27" >z (Wh/km)</th>
#       <th id="T_12fc0_level0_col28" class="col_heading level0 col28" >IT</th>
#       <th id="T_12fc0_level0_col29" class="col_heading level0 col29" >Ernedc (g/km)</th>
#       <th id="T_12fc0_level0_col30" class="col_heading level0 col30" >Erwltp (g/km)</th>
#       <th id="T_12fc0_level0_col31" class="col_heading level0 col31" >De</th>
#       <th id="T_12fc0_level0_col32" class="col_heading level0 col32" >Vf</th>
#       <th id="T_12fc0_level0_col33" class="col_heading level0 col33" >Status</th>
#       <th id="T_12fc0_level0_col34" class="col_heading level0 col34" >year</th>
#       <th id="T_12fc0_level0_col35" class="col_heading level0 col35" >Date of registration</th>
#       <th id="T_12fc0_level0_col36" class="col_heading level0 col36" >Fuel consumption </th>
#       <th id="T_12fc0_level0_col37" class="col_heading level0 col37" >Electric range (km)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12fc0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12fc0_row0_col0" class="data row0 col0" >295039</td>
#       <td id="T_12fc0_row0_col1" class="data row0 col1" >ES</td>
#       <td id="T_12fc0_row0_col2" class="data row0 col2" >IP MQB37WZ_A1_0589 VSS 1</td>
#       <td id="T_12fc0_row0_col3" class="data row0 col3" >VW-SAIC</td>
#       <td id="T_12fc0_row0_col4" class="data row0 col4" >SEAT</td>
#       <td id="T_12fc0_row0_col5" class="data row0 col5" >SEAT SA</td>
#       <td id="T_12fc0_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_12fc0_row0_col7" class="data row0 col7" >E9*2007/46*3167*07</td>
#       <td id="T_12fc0_row0_col8" class="data row0 col8" >KL</td>
#       <td id="T_12fc0_row0_col9" class="data row0 col9" >SBDTTCX0</td>
#       <td id="T_12fc0_row0_col10" class="data row0 col10" >FD7SFD7GC0024BIVL1BAF</td>
#       <td id="T_12fc0_row0_col11" class="data row0 col11" >SEAT</td>
#       <td id="T_12fc0_row0_col12" class="data row0 col12" >LEON</td>
#       <td id="T_12fc0_row0_col13" class="data row0 col13" >M1</td>
#       <td id="T_12fc0_row0_col14" class="data row0 col14" >M1</td>
#       <td id="T_12fc0_row0_col15" class="data row0 col15" >1</td>
#       <td id="T_12fc0_row0_col16" class="data row0 col16" >1448.000</td>
#       <td id="T_12fc0_row0_col17" class="data row0 col17" >nan</td>
#       <td id="T_12fc0_row0_col18" class="data row0 col18" >104.000</td>
#       <td id="T_12fc0_row0_col19" class="data row0 col19" >118.000</td>
#       <td id="T_12fc0_row0_col20" class="data row0 col20" >2669.000</td>
#       <td id="T_12fc0_row0_col21" class="data row0 col21" >1550.000</td>
#       <td id="T_12fc0_row0_col22" class="data row0 col22" >1520.000</td>
#       <td id="T_12fc0_row0_col23" class="data row0 col23" >DIESEL</td>
#       <td id="T_12fc0_row0_col24" class="data row0 col24" >M</td>
#       <td id="T_12fc0_row0_col25" class="data row0 col25" >1968.000</td>
#       <td id="T_12fc0_row0_col26" class="data row0 col26" >110.000</td>
#       <td id="T_12fc0_row0_col27" class="data row0 col27" >nan</td>
#       <td id="T_12fc0_row0_col28" class="data row0 col28" >e9  28 29</td>
#       <td id="T_12fc0_row0_col29" class="data row0 col29" >nan</td>
#       <td id="T_12fc0_row0_col30" class="data row0 col30" >1.700</td>
#       <td id="T_12fc0_row0_col31" class="data row0 col31" >nan</td>
#       <td id="T_12fc0_row0_col32" class="data row0 col32" >nan</td>
#       <td id="T_12fc0_row0_col33" class="data row0 col33" >P</td>
#       <td id="T_12fc0_row0_col34" class="data row0 col34" >2021</td>
#       <td id="T_12fc0_row0_col35" class="data row0 col35" >2021-01-11</td>
#       <td id="T_12fc0_row0_col36" class="data row0 col36" >4.500</td>
#       <td id="T_12fc0_row0_col37" class="data row0 col37" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_12fc0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_12fc0_row1_col0" class="data row1 col0" >295040</td>
#       <td id="T_12fc0_row1_col1" class="data row1 col1" >ES</td>
#       <td id="T_12fc0_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_12fc0_row1_col3" class="data row1 col3" >VW-SAIC</td>
#       <td id="T_12fc0_row1_col4" class="data row1 col4" >VOLKSWAGEN</td>
#       <td id="T_12fc0_row1_col5" class="data row1 col5" >VOLKSWAGEN AG</td>
#       <td id="T_12fc0_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_12fc0_row1_col7" class="data row1 col7" >E13*2007/46*1845*17</td>
#       <td id="T_12fc0_row1_col8" class="data row1 col8" >A1</td>
#       <td id="T_12fc0_row1_col9" class="data row1 col9" >DLAAX0AC4</td>
#       <td id="T_12fc0_row1_col10" class="data row1 col10" >FM6FM6AJ0254BI1AANNMI</td>
#       <td id="T_12fc0_row1_col11" class="data row1 col11" >VOLKSWAGEN</td>
#       <td id="T_12fc0_row1_col12" class="data row1 col12" >T-ROC</td>
#       <td id="T_12fc0_row1_col13" class="data row1 col13" >M1</td>
#       <td id="T_12fc0_row1_col14" class="data row1 col14" >M1</td>
#       <td id="T_12fc0_row1_col15" class="data row1 col15" >1</td>
#       <td id="T_12fc0_row1_col16" class="data row1 col16" >1294.000</td>
#       <td id="T_12fc0_row1_col17" class="data row1 col17" >nan</td>
#       <td id="T_12fc0_row1_col18" class="data row1 col18" >nan</td>
#       <td id="T_12fc0_row1_col19" class="data row1 col19" >137.000</td>
#       <td id="T_12fc0_row1_col20" class="data row1 col20" >2590.000</td>
#       <td id="T_12fc0_row1_col21" class="data row1 col21" >1546.000</td>
#       <td id="T_12fc0_row1_col22" class="data row1 col22" >1540.000</td>
#       <td i
# <class 'pandas.io.formats.style.Styler'>
# <style type="text/css">
# #T_fb298 th {
#   background-color: steelblue;
#   color: white;
# }
# #T_fb298 tr:nth-of-type(odd) {
#   background-color: aliceblue;
# }
# #T_fb298 tr:nth-of-type(even) {
#   background-color: white;
# }
# </style>
# <table id="T_fb298">
#   <caption><h2>DONNEES BRUTES: FR/ALL 2021</h2></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb298_level0_col0" class="col_heading level0 col0" >Column</th>
#       <th id="T_fb298_level0_col1" class="col_heading level0 col1" >Non-Null Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb298_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fb298_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_fb298_row0_col1" class="data row0 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fb298_row1_col0" class="data row1 col0" >Country</td>
#       <td id="T_fb298_row1_col1" class="data row1 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fb298_row2_col0" class="data row2 col0" >VFN</td>
#       <td id="T_fb298_row2_col1" class="data row2 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fb298_row3_col0" class="data row3 col0" >Mp</td>
#       <td id="T_fb298_row3_col1" class="data row3 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fb298_row4_col0" class="data row4 col0" >Mh</td>
#       <td id="T_fb298_row4_col1" class="data row4 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fb298_row5_col0" class="data row5 col0" >Man</td>
#       <td id="T_fb298_row5_col1" class="data row5 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fb298_row6_col0" class="data row6 col0" >MMS</td>
#       <td id="T_fb298_row6_col1" class="data row6 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fb298_row7_col0" class="data row7 col0" >Tan</td>
#       <td id="T_fb298_row7_col1" class="data row7 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fb298_row8_col0" class="data row8 col0" >T</td>
#       <td id="T_fb298_row8_col1" class="data row8 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fb298_row9_col0" class="data row9 col0" >Va</td>
#       <td id="T_fb298_row9_col1" class="data row9 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fb298_row10_col0" class="data row10 col0" >Ve</td>
#       <td id="T_fb298_row10_col1" class="data row10 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fb298_row11_col0" class="data row11 col0" >Mk</td>
#       <td id="T_fb298_row11_col1" class="data row11 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fb298_row12_col0" class="data row12 col0" >Cn</td>
#       <td id="T_fb298_row12_col1" class="data row12 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_fb298_row13_col0" class="data row13 col0" >Ct</td>
#       <td id="T_fb298_row13_col1" class="data row13 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_fb298_row14_col0" class="data row14 col0" >Cr</td>
#       <td id="T_fb298_row14_col1" class="data row14 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_fb298_row15_col0" class="data row15 col0" >r</td>
#       <td id="T_fb298_row15_col1" class="data row15 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_fb298_row16_col0" class="data row16 col0" >m (kg)</td>
#       <td id="T_fb298_row16_col1" class="data row16 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_fb298_row17_col0" class="data row17 col0" >Mt</td>
#       <td id="T_fb298_row17_col1" class="data row17 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_fb298_row18_col0" class="data row18 col0" >Enedc (g/km)</td>
#       <td id="T_fb298_row18_col1" class="data row18 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_fb298_row19_col0" class="data row19 col0" >Ewltp (g/km)</td>
#       <td id="T_fb298_row19_col1" class="data row19 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_fb298_row20_col0" class="data row20 col0" >W (mm)</td>
#       <td id="T_fb298_row20_col1" class="data row20 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_fb298_row21_col0" class="data row21 col0" >At1 (mm)</td>
#       <td id="T_fb298_row21_col1" class="data row21 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_fb298_row22_col0" class="data row22 col0" >At2 (mm)</td>
#       <td id="T_fb298_row22_col1" class="data row22 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_fb298_row23_col0" class="data row23 col0" >Ft</td>
#       <td id="T_fb298_row23_col1" class="data row23 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_fb298_row24_col0" class="data row24 col0" >Fm</td>
#       <td id="T_fb298_row24_col1" class="data row24 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_fb298_row25_col0" class="data row25 col0" >ec (cm3)</td>
#       <td id="T_fb298_row25_col1" class="data row25 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_fb298_row26_col0" class="data row26 col0" >ep (KW)</td>
#       <td id="T_fb298_row26_col1" class="data row26 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_fb298_row27_col0" class="data row27 col0" >z (Wh/km)</td>
#       <td id="T_fb298_row27_col1" class="data row27 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_fb298_row28_col0" class="data row28 col0" >IT</td>
#       <td id="T_fb298_row28_col1" class="data row28 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_fb298_row29_col0" class="data row29 col0" >Ernedc (g/km)</td>
#       <td id="T_fb298_row29_col1" class="data row29 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_fb298_row30_col0" class="data row30 col0" >Erwltp (g/km)</td>
#       <td id="T_fb298_row30_col1" class="data row30 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_fb298_level0_row31" class="row_heading level0 row31" >31</th>
#       <td id="T_fb298_row31_col0" clas
# <class 'pandas.io.formats.style.Styler'>
# <style type="text/css">
# #T_ba1ba th {
#   background-color: steelblue;
#   color: white;
# }
# #T_ba1ba tr:nth-of-type(odd) {
#   background-color: aliceblue;
# }
# #T_ba1ba tr:nth-of-type(even) {
#   background-color: white;
# }
# </style>
# <table id="T_ba1ba">
#   <caption><h2>DONNEES BRUTES: FR/ALL 2021</h2></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba1ba_level0_col0" class="col_heading level0 col0" >Info</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba1ba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ba1ba_row0_col0" class="data row0 col0" >RangeIndex: 9920108 entries, 0 to 9920107</td>
#     </tr>
#     <tr>
#       <th id="T_ba1ba_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ba1ba_row1_col0" class="data row1 col0" >Data columns (total 38 columns):</td>
#     </tr>
#     <tr>
#       <th id="T_ba1ba_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ba1ba_row2_col0" class="data row2 col0" > 37  Electric range (km)   float64</td>
#     </tr>
#     <tr>
#       <th id="T_ba1ba_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ba1ba_row3_col0" class="data row3 col0" >dtypes: float64(17), int64(3), object(18)</td>
#     </tr>
#     <tr>
#       <th id="T_ba1ba_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ba1ba_row4_col0" class="data row4 col0" >memory usage: 2.8+ GB</td>
#     </tr>
#   </tbody>
# </table>
# <class 'pandas.io.formats.style.Styler'>
# <style type="text/css">
# #T_c7315 th {
#   background-color: steelblue;
#   color: white;
# }
# #T_c7315 tr:nth-of-type(odd) {
#   background-color: aliceblue;
# }
# #T_c7315 tr:nth-of-type(even) {
#   background-color: white;
# }
# #T_c7315_row0_col1, #T_c7315_row1_col1, #T_c7315_row2_col1, #T_c7315_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightcoral 100.0%, transparent 100.0%);
# }
# #T_c7315_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightcoral 85.2%, transparent 85.2%);
# }
# #T_c7315_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightcoral 83.6%, transparent 83.6%);
# }
# #T_c7315_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightcoral 75.6%, transparent 75.6%);
# }
# #T_c7315_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightcoral 56.7%, transparent 56.7%);
# }
# #T_c7315_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightcoral 54.1%, transparent 54.1%);
# }
# #T_c7315_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightcoral 40.7%, transparent 40.7%);
# }
# #T_c7315_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightcoral 19.5%, transparent 19.5%);
# }
# #T_c7315_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightcoral 15.8%, transparent 15.8%);
# }
# #T_c7315_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightcoral 15.7%, transparent 15.7%);
# }
# #T_c7315_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightcoral 10.5%, transparent 10.5%);
# }
# #T_c7315_row14_col1, #T_c7315_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightcoral 10.1%, transparent 10.1%);
# }
# #T_c7315_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightcoral 3.2%, transparent 3.2%);
# }
# #T_c7315_row17_col1, #T_c7315_row18_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightcoral 0.9%, transparent 0.9%);
# }
# #T_c7315_row19_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightcoral 0.5%, transparent 0.5%);
# }
# #T_c7315_row20_col1, #T_c7315_row21_col1, #T_c7315_row22_col1, #T_c7315_row23_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightcoral 0.2%, transparent 0.2%);
# }
# #T_c7315_row24_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightcoral 0.1%, transparent 0.1%);
# }
# #T_c7315_row25_col1, #T_c7315_row26_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightcoral 0.0%, transparent 0.0%);
# }
# #T_c7315_row27_col1, #T_c7315_row28_col1, #T_c7315_row29_col1, #T_c7315_row30_col1, #T_c7315_row31_col1, #T_c7315_row32_col1, #T_c7315_row33_col1, #T_c7315_row34_col1, #T_c7315_row35_col1, #T_c7315_row36_col1, #T_c7315_row37_col1 {
#   width: 10em;
# }
# </style>
# <table id="T_c7315">
#   <caption><h2>PART DE VALEURS MANQUANTES DANS LE JEU DE DONNEES: FR/ALL 2021</h2></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7315_level0_col0" class="col_heading level0 col0" >Colonne</th>
#       <th id="T_c7315_level0_col1" class="col_heading level0 col1" >Valeurs manquantes (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7315_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7315_row0_col0" class="data row0 col0" >Vf</td>
#       <td id="T_c7315_row0_col1" class="data row0 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_c7315_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7315_row1_col0" class="data row1 col0" >MMS</td>
#       <td id="T_c7315_row1_col1" class="data row1 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_c7315_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c7315_row2_col0" class="data row2 col0" >Ernedc (g/km)</td>
#       <td id="T_c7315_row2_col1" class="data row2 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_c7315_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c7315_row3_col0" class="data row3 col0" >De</td>
#       <td id="T_c7315_row3_col1" class="data row3 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_c7315_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c7315_row4_col0" class="data row4 col0" >Electric range (km)</td>
#       <td id="T_c7315_row4_col1" class="data row4 col1" >85.24%</td>
#     </tr>
#     <tr>
#       <th id="T_c7315_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c7315_row5_col0" class="data row5 col0" >z (Wh/km)</td>
#       <td id="T_c7315_row5_col1" class="data row5 col1" >83.63%</td>
#     </tr>
#     <tr>
#       <th id="T_c7315_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c7315_row6_col0" class="data row6 col0" >Enedc (g/km)</td>
#       <td id="T_c7315_row6_col1" class="data row6 col1" >75.63%</td>
#     </tr>
#     <tr>
#       <th id="T_c7315_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c7315_row7_col0" class="data row7 col0" >Erwltp (g/km)</td>
#       <td id="T_c7315_row7_col1" class="data row7 col1" >56.70%</td>
#     </tr>
#     <tr>
#       <th id="T_c7315_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c7315_row8_col0" class="data row8 col0" >IT</td>
#       <td id="T_c7315_row8_col1" class="data row8 col1" >54.13%</td>
#     </tr>
#     <tr>
#       <th id="T_c7315_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c7315_row9_col0" class="data row9 col0" >Fuel consumption </td>
#       <td id="T_c7315_row9_col1" class="data row9 col1" >40.73%</td>
#     </tr>
#     <tr>
#       <th id="T_c7315_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c7315_row10_col0" class="data row10 col0" >Mt</td>
#       <td id="T_c7315_row10_col1" class="data row10 col1" >19.52%</td>
#     </tr>
#     <tr>
#       <th id="T_c7315_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c7315_row11_col0" class="data row11 col0" >At2 (mm)</td>
#       <td id="T_c7315_row11_col1" class="data row11 col1" >15.78%</td>
#     </tr>
#     <tr>
#       <th id="T_c7315_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c7315_row12_col0" class="data row12 col0" >At1 (mm)</td>
#       <td id="T_c7315_row12_col1" class="data row12 col1" >15.74%</td>
#     </tr>
#     <tr>
#       <th id="T_c7315_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c7315_row13_col0" class="data row13 col0" >Date of registration</td>
#       <td id="T_c7315_row13_col1" class="data row13 col1" >10.54%</td>
#     </tr>
#     <tr>
#       <th id="T_c7315_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c7315_row14_col0" class="data row14 col0" >VFN</td>
#       <td id="T_c7315_row14_col1" class="data row14 col1" >10.13%</td>
#     </tr>
#     <tr>
#       <th id="T_c7315_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c7315_row15_col0" class="data row15 col0" >ec (cm3)</td>
#       <td id="T_c7315_row15_col1" class="data row15 col1" >10.09%</td>
#     </tr>
#     <tr>
#       <th id="T_c7315_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c7315_row16_col0" class="data row16 col0" >Mp</td>
#       <td id="T_c7315_row16_col1" class="data row16 col1" >3.20%</td>
#     </tr>
#     <tr>
#       <th id="T_c7315_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c7315_row17_col0" class="data row17 col0" >ep (KW)</td>
#       <td id="T_c7315_row17_col1" class="data row17 col1" >0.90%</td>
#     </tr>
#     <tr>
#       <th id="T_c7315_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c7315_row18_col0" class="data row18 col0" >Ewltp (g/km)</td>
#       <td id="T_c7315_row18_col1" class="data row18 col1" >0.85%</td>
#     </tr>
#     <tr>
#       <th id="T_c7315_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_c7315_row19_col0" class="data row19 col0" >Ve</td>
#       <td id="T_c7315_row19_col1" class="data row19 col1" >0.47%</td>
#     </tr>
#     <tr>
#       <th id="T_c7315_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_c7315_row20_col0" class="data row20 col0" >Tan</td>
#       <td id="T
# <class 'pandas.io.formats.style.Styler'>
# Incomplete rows dropped:461538
# TOTAL NUMBER OF ROWS DROPPED:461538
# <style type="text/css">
# #T_484bd th {
#   background-color: steelblue;
#   color: white;
# }
# #T_484bd tr:nth-of-type(odd) {
#   background-color: aliceblue;
# }
# #T_484bd tr:nth-of-type(even) {
#   background-color: white;
# }
# </style>
# <table id="T_484bd">
#   <caption><h2>DONNEES NETTOYEES: FR/ALL 2021</h2></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_484bd_level0_col0" class="col_heading level0 col0" >Column</th>
#       <th id="T_484bd_level0_col1" class="col_heading level0 col1" >Non-Null Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_484bd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_484bd_row0_col0" class="data row0 col0" >Pool</td>
#       <td id="T_484bd_row0_col1" class="data row0 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_484bd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_484bd_row1_col0" class="data row1 col0" >MassRunningOrder</td>
#       <td id="T_484bd_row1_col1" class="data row1 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_484bd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_484bd_row2_col0" class="data row2 col0" >Co2EmissionsWltp</td>
#       <td id="T_484bd_row2_col1" class="data row2 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_484bd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_484bd_row3_col0" class="data row3 col0" >BaseWheel</td>
#       <td id="T_484bd_row3_col1" class="data row3 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_484bd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_484bd_row4_col0" class="data row4 col0" >FuelType</td>
#       <td id="T_484bd_row4_col1" class="data row4 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_484bd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_484bd_row5_col0" class="data row5 col0" >EnginePower</td>
#       <td id="T_484bd_row5_col1" class="data row5 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_484bd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_484bd_row6_col0" class="data row6 col0" >InnovativeTechnology</td>
#       <td id="T_484bd_row6_col1" class="data row6 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_484bd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_484bd_row7_col0" class="data row7 col0" >ElectricRange</td>
#       <td id="T_484bd_row7_col1" class="data row7 col1" >float64</td>
#     </tr>
#   </tbody>
# </table>
# <class 'pandas.io.formats.style.Styler'>
# <style type="text/css">
# #T_1a471 th {
#   background-color: steelblue;
#   color: white;
# }
# #T_1a471 tr:nth-of-type(odd) {
#   background-color: aliceblue;
# }
# #T_1a471 tr:nth-of-type(even) {
#   background-color: white;
# }
# </style>
# <table id="T_1a471">
#   <caption><h2>DONNEES NETTOYEES: FR/ALL 2021</h2></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a471_level0_col0" class="col_heading level0 col0" >Info</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a471_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1a471_row0_col0" class="data row0 col0" >Index: 9458570 entries, 0 to 9920107</td>
#     </tr>
#     <tr>
#       <th id="T_1a471_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1a471_row1_col0" class="data row1 col0" >Data columns (total 8 columns):</td>
#     </tr>
#     <tr>
#       <th id="T_1a471_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1a471_row2_col0" class="data row2 col0" > 7   ElectricRange         float64</td>
#     </tr>
#     <tr>
#       <th id="T_1a471_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1a471_row3_col0" class="data row3 col0" >dtypes: float64(5), int64(1), object(2)</td>
#     </tr>
#     <tr>
#       <th id="T_1a471_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1a471_row4_col0" class="data row4 col0" >memory usage: 649.5+ MB</td>
#     </tr>
#   </tbody>
# </table>
# <class 'pandas.io.formats.style.Styler'>
# <style type="text/css">
# #T_95fe2 th {
#   background-color: steelblue;
#   color: white;
# }
# #T_95fe2 tr:nth-of-type(odd) {
#   background-color: aliceblue;
# }
# #T_95fe2 tr:nth-of-type(even) {
#   background-color: white;
# }
# </style>
# <table id="T_95fe2">
#   <caption><h2>STATISTIQUES DESCRIPTIVES: FR/ALL 2021</h2></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95fe2_level0_col0" class="col_heading level0 col0" >Colonne</th>
#       <th id="T_95fe2_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_95fe2_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_95fe2_level0_col3" class="col_heading level0 col3" >std</th>
#       <th id="T_95fe2_level0_col4" class="col_heading level0 col4" >min</th>
#       <th id="T_95fe2_level0_col5" class="col_heading level0 col5" >25%</th>
#       <th id="T_95fe2_level0_col6" class="col_heading level0 col6" >50%</th>
#       <th id="T_95fe2_level0_col7" class="col_heading level0 col7" >75%</th>
#       <th id="T_95fe2_level0_col8" class="col_heading level0 col8" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95fe2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_95fe2_row0_col0" class="data row0 col0" >MassRunningOrder</td>
#       <td id="T_95fe2_row0_col1" class="data row0 col1" >9458570.000</td>
#       <td id="T_95fe2_row0_col2" class="data row0 col2" >1473.432</td>
#       <td id="T_95fe2_row0_col3" class="data row0 col3" >328.351</td>
#       <td id="T_95fe2_row0_col4" class="data row0 col4" >860.000</td>
#       <td id="T_95fe2_row0_col5" class="data row0 col5" >1239.000</td>
#       <td id="T_95fe2_row0_col6" class="data row0 col6" >1414.000</td>
#       <td id="T_95fe2_row0_col7" class="data row0 col7" >1639.000</td>
#       <td id="T_95fe2_row0_col8" class="data row0 col8" >3950.000</td>
#     </tr>
#     <tr>
#       <th id="T_95fe2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_95fe2_row1_col0" class="data row1 col0" >Co2EmissionsWltp</td>
#       <td id="T_95fe2_row1_col1" class="data row1 col1" >9458570.000</td>
#       <td id="T_95fe2_row1_col2" class="data row1 col2" >115.319</td>
#       <td id="T_95fe2_row1_col3" class="data row1 col3" >52.398</td>
#       <td id="T_95fe2_row1_col4" class="data row1 col4" >0.000</td>
#       <td id="T_95fe2_row1_col5" class="data row1 col5" >112.000</td>
#       <td id="T_95fe2_row1_col6" class="data row1 col6" >126.000</td>
#       <td id="T_95fe2_row1_col7" class="data row1 col7" >141.000</td>
#       <td id="T_95fe2_row1_col8" class="data row1 col8" >572.000</td>
#     </tr>
#     <tr>
#       <th id="T_95fe2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_95fe2_row2_col0" class="data row2 col0" >BaseWheel</td>
#       <td id="T_95fe2_row2_col1" class="data row2 col1" >9458570.000</td>
#       <td id="T_95fe2_row2_col2" class="data row2 col2" >2651.779</td>
#       <td id="T_95fe2_row2_col3" class="data row2 col3" >164.930</td>
#       <td id="T_95fe2_row2_col4" class="data row2 col4" >984.000</td>
#       <td id="T_95fe2_row2_col5" class="data row2 col5" >2560.000</td>
#       <td id="T_95fe2_row2_col6" class="data row2 col6" >2640.000</td>
#       <td id="T_95fe2_row2_col7" class="data row2 col7" >2712.000</td>
#       <td id="T_95fe2_row2_col8" class="data row2 col8" >5840.000</td>
#     </tr>
#     <tr>
#       <th id="T_95fe2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_95fe2_row3_col0" class="data row3 col0" >EnginePower</td>
#       <td id="T_95fe2_row3_col1" class="data row3 col1" >9458570.000</td>
#       <td id="T_95fe2_row3_col2" class="data row3 col2" >100.704</td>
#       <td id="T_95fe2_row3_col3" class="data row3 col3" >48.388</td>
#       <td id="T_95fe2_row3_col4" class="data row3 col4" >9.000</td>
#       <td id="T_95fe2_row3_col5" class="data row3 col5" >70.000</td>
#       <td id="T_95fe2_row3_col6" class="data row3 col6" >92.000</td>
#       <td id="T_95fe2_row3_col7" class="data row3 col7" >110.000</td>
#       <td id="T_95fe2_row3_col8" class="data row3 col8" >1177.000</td>
#     </tr>
#     <tr>
#       <th id="T_95fe2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_95fe2_row4_col0" class="data row4 col0" >InnovativeTechnology</td>
#       <td id="T_95fe2_row4_col1" class="data row4 col1" >9458570.000</td>
#       <td id="T_95fe2_row4_col2" class="data row4 col2" >0.476</td>
#       <td id="T_95fe2_row4_col3" class="data row4 col3" >0.499</td>
#       <td id="T_95fe2_row4_col4" class="data row4 col4" >0.000</td>
#       <td id="T_95fe2_row4_col5" class="data row4 col5" >0.000</td>
#       <td id="T_95fe2_row4_col6" class="data row4 col6" >0.000</td>
#       <td id="T_95fe2_row4_col7" class="data row4 col7" >1.000</td>
#       <td id="T_95fe2_row4_col8" class="data row4 col8" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_95fe2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_95fe2_row5_col0" class="data row5 col0" >ElectricRange</td>
#       <td id="T_95fe2_row5_col1" class="data row5 col1" >1284293.000</td>
#       <td id="T_95fe2_row5_col2" class="data row5 col2" >217.285</td>
#       <td id="T_95fe2_row5_col3" class="data row5 col3" >180.171</td>
#       <td id="T_95fe2_row5_col4" class="data row5 col4" >1.000</td>
#       <td id="T_95fe2_row5_col5" class="data row5 col5" >59.000</td>
#       <td id="T_95fe2_row5_col6" class="data row5 col6" >99.000</td>
#       <td id="T_95fe2_row5_col7" class="data row5 col7" >390.000</td>
#       <td id="T_95fe2_row5_col8" class="data row5 col8" >808.000</td>
#     </tr>
#   </tbody>
# </table>
# <class 'pandas.io.formats.style.Styler'>
# Data saved to ../data/processed/co2_regression_20240115-195601

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9458570 entries, 0 to 9920107
# Data columns (total 28 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   MassRunningOrder                 float64
#  1   Co2EmissionsWltp                 float64
#  2   BaseWheel                        float64
#  3   EnginePower                      float64
#  4   InnovativeTechnology             int64
#  5   ElectricRange                    float64
#  6   Pool_BMW                         int64
#  7   Pool_FORD                        int64
#  8   Pool_HYUNDAI                     int64
#  9   Pool_KIA                         int64
#  10  Pool_MAZDA-SUBARU-SUZUKI-TOYOTA  int64
#  11  Pool_MERCEDES-BENZ               int64
#  12  Pool_RENAULT-NISSAN-MITSUBISHI   int64
#  13  Pool_STELLANTIS                  int64
#  14  Pool_TESLA                       int64
#  15  Pool_VW-SAIC                     int64
#  16  FuelType_DIESEL                  int64
#  17  FuelType_DIESEL/ELECTRIC         int64
#  18  FuelType_E85                     int64
#  19  FuelType_ELECTRIC                int64
#  20  FuelType_HYDROGEN                int64
#  21  FuelType_LPG                     int64
#  22  FuelType_NG                      int64
#  23  FuelType_NG-BIOMETHANE           int64
#  24  FuelType_PETROL                  int64
#  25  FuelType_PETROL/ELECTRIC         int64
#  26  FuelType_UNKNOWN                 int64
#  27  FuelType_petrol/electric         int64
# dtypes: float64(5), int64(23)
# memory usage: 2.3 GB

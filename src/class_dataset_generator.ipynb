# %%
import pandas as pd
import kaggle
import auto_co2 as co2
import importlib
import warnings
warnings.filterwarnings('ignore', 'SettingWithCopyWarning')
importlib.reload(co2)
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /home/mln/.kaggle/kaggle.json'
# <module 'auto_co2' from '/home/mln/GIT/car-co2-prediction_pre-release/src/auto_co2/__init__.py'>

# %%
df = co2.data.load_co2_data()
co2.styles.displayer(df)
# Out:
# <style type="text/css">
# #T_6a86f th {
#   background-color: steelblue;
#   color: white;
# }
# #T_6a86f tr:nth-of-type(odd) {
#   background-color: aliceblue;
# }
# #T_6a86f tr:nth-of-type(even) {
#   background-color: white;
# }
# </style>
# <table id="T_6a86f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a86f_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_6a86f_level0_col1" class="col_heading level0 col1" >Country</th>
#       <th id="T_6a86f_level0_col2" class="col_heading level0 col2" >VFN</th>
#       <th id="T_6a86f_level0_col3" class="col_heading level0 col3" >Mp</th>
#       <th id="T_6a86f_level0_col4" class="col_heading level0 col4" >Mh</th>
#       <th id="T_6a86f_level0_col5" class="col_heading level0 col5" >Man</th>
#       <th id="T_6a86f_level0_col6" class="col_heading level0 col6" >MMS</th>
#       <th id="T_6a86f_level0_col7" class="col_heading level0 col7" >Tan</th>
#       <th id="T_6a86f_level0_col8" class="col_heading level0 col8" >T</th>
#       <th id="T_6a86f_level0_col9" class="col_heading level0 col9" >Va</th>
#       <th id="T_6a86f_level0_col10" class="col_heading level0 col10" >Ve</th>
#       <th id="T_6a86f_level0_col11" class="col_heading level0 col11" >Mk</th>
#       <th id="T_6a86f_level0_col12" class="col_heading level0 col12" >Cn</th>
#       <th id="T_6a86f_level0_col13" class="col_heading level0 col13" >Ct</th>
#       <th id="T_6a86f_level0_col14" class="col_heading level0 col14" >Cr</th>
#       <th id="T_6a86f_level0_col15" class="col_heading level0 col15" >r</th>
#       <th id="T_6a86f_level0_col16" class="col_heading level0 col16" >m (kg)</th>
#       <th id="T_6a86f_level0_col17" class="col_heading level0 col17" >Mt</th>
#       <th id="T_6a86f_level0_col18" class="col_heading level0 col18" >Enedc (g/km)</th>
#       <th id="T_6a86f_level0_col19" class="col_heading level0 col19" >Ewltp (g/km)</th>
#       <th id="T_6a86f_level0_col20" class="col_heading level0 col20" >W (mm)</th>
#       <th id="T_6a86f_level0_col21" class="col_heading level0 col21" >At1 (mm)</th>
#       <th id="T_6a86f_level0_col22" class="col_heading level0 col22" >At2 (mm)</th>
#       <th id="T_6a86f_level0_col23" class="col_heading level0 col23" >Ft</th>
#       <th id="T_6a86f_level0_col24" class="col_heading level0 col24" >Fm</th>
#       <th id="T_6a86f_level0_col25" class="col_heading level0 col25" >ec (cm3)</th>
#       <th id="T_6a86f_level0_col26" class="col_heading level0 col26" >ep (KW)</th>
#       <th id="T_6a86f_level0_col27" class="col_heading level0 col27" >z (Wh/km)</th>
#       <th id="T_6a86f_level0_col28" class="col_heading level0 col28" >IT</th>
#       <th id="T_6a86f_level0_col29" class="col_heading level0 col29" >Ernedc (g/km)</th>
#       <th id="T_6a86f_level0_col30" class="col_heading level0 col30" >Erwltp (g/km)</th>
#       <th id="T_6a86f_level0_col31" class="col_heading level0 col31" >De</th>
#       <th id="T_6a86f_level0_col32" class="col_heading level0 col32" >Vf</th>
#       <th id="T_6a86f_level0_col33" class="col_heading level0 col33" >Status</th>
#       <th id="T_6a86f_level0_col34" class="col_heading level0 col34" >year</th>
#       <th id="T_6a86f_level0_col35" class="col_heading level0 col35" >Date of registration</th>
#       <th id="T_6a86f_level0_col36" class="col_heading level0 col36" >Fuel consumption </th>
#       <th id="T_6a86f_level0_col37" class="col_heading level0 col37" >Electric range (km)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a86f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a86f_row0_col0" class="data row0 col0" >295039</td>
#       <td id="T_6a86f_row0_col1" class="data row0 col1" >ES</td>
#       <td id="T_6a86f_row0_col2" class="data row0 col2" >IP MQB37WZ_A1_0589 VSS 1</td>
#       <td id="T_6a86f_row0_col3" class="data row0 col3" >VW-SAIC</td>
#       <td id="T_6a86f_row0_col4" class="data row0 col4" >SEAT</td>
#       <td id="T_6a86f_row0_col5" class="data row0 col5" >SEAT SA</td>
#       <td id="T_6a86f_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_6a86f_row0_col7" class="data row0 col7" >E9*2007/46*3167*07</td>
#       <td id="T_6a86f_row0_col8" class="data row0 col8" >KL</td>
#       <td id="T_6a86f_row0_col9" class="data row0 col9" >SBDTTCX0</td>
#       <td id="T_6a86f_row0_col10" class="data row0 col10" >FD7SFD7GC0024BIVL1BAF</td>
#       <td id="T_6a86f_row0_col11" class="data row0 col11" >SEAT</td>
#       <td id="T_6a86f_row0_col12" class="data row0 col12" >LEON</td>
#       <td id="T_6a86f_row0_col13" class="data row0 col13" >M1</td>
#       <td id="T_6a86f_row0_col14" class="data row0 col14" >M1</td>
#       <td id="T_6a86f_row0_col15" class="data row0 col15" >1</td>
#       <td id="T_6a86f_row0_col16" class="data row0 col16" >1448.000</td>
#       <td id="T_6a86f_row0_col17" class="data row0 col17" >nan</td>
#       <td id="T_6a86f_row0_col18" class="data row0 col18" >104.000</td>
#       <td id="T_6a86f_row0_col19" class="data row0 col19" >118.000</td>
#       <td id="T_6a86f_row0_col20" class="data row0 col20" >2669.000</td>
#       <td id="T_6a86f_row0_col21" class="data row0 col21" >1550.000</td>
#       <td id="T_6a86f_row0_col22" class="data row0 col22" >1520.000</td>
#       <td id="T_6a86f_row0_col23" class="data row0 col23" >DIESEL</td>
#       <td id="T_6a86f_row0_col24" class="data row0 col24" >M</td>
#       <td id="T_6a86f_row0_col25" class="data row0 col25" >1968.000</td>
#       <td id="T_6a86f_row0_col26" class="data row0 col26" >110.000</td>
#       <td id="T_6a86f_row0_col27" class="data row0 col27" >nan</td>
#       <td id="T_6a86f_row0_col28" class="data row0 col28" >e9  28 29</td>
#       <td id="T_6a86f_row0_col29" class="data row0 col29" >nan</td>
#       <td id="T_6a86f_row0_col30" class="data row0 col30" >1.700</td>
#       <td id="T_6a86f_row0_col31" class="data row0 col31" >nan</td>
#       <td id="T_6a86f_row0_col32" class="data row0 col32" >nan</td>
#       <td id="T_6a86f_row0_col33" class="data row0 col33" >P</td>
#       <td id="T_6a86f_row0_col34" class="data row0 col34" >2021</td>
#       <td id="T_6a86f_row0_col35" class="data row0 col35" >2021-01-11</td>
#       <td id="T_6a86f_row0_col36" class="data row0 col36" >4.500</td>
#       <td id="T_6a86f_row0_col37" class="data row0 col37" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_6a86f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6a86f_row1_col0" class="data row1 col0" >295040</td>
#       <td id="T_6a86f_row1_col1" class="data row1 col1" >ES</td>
#       <td id="T_6a86f_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_6a86f_row1_col3" class="data row1 col3" >VW-SAIC</td>
#       <td id="T_6a86f_row1_col4" class="data row1 col4" >VOLKSWAGEN</td>
#       <td id="T_6a86f_row1_col5" class="data row1 col5" >VOLKSWAGEN AG</td>
#       <td id="T_6a86f_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_6a86f_row1_col7" class="data row1 col7" >E13*2007/46*1845*17</td>
#       <td id="T_6a86f_row1_col8" class="data row1 col8" >A1</td>
#       <td id="T_6a86f_row1_col9" class="data row1 col9" >DLAAX0AC4</td>
#       <td id="T_6a86f_row1_col10" class="data row1 col10" >FM6FM6AJ0254BI1AANNMI</td>
#       <td id="T_6a86f_row1_col11" class="data row1 col11" >VOLKSWAGEN</td>
#       <td id="T_6a86f_row1_col12" class="data row1 col12" >T-ROC</td>
#       <td id="T_6a86f_row1_col13" class="data row1 col13" >M1</td>
#       <td id="T_6a86f_row1_col14" class="data row1 col14" >M1</td>
#       <td id="T_6a86f_row1_col15" class="data row1 col15" >1</td>
#       <td id="T_6a86f_row1_col16" class="data row1 col16" >1294.000</td>
#       <td id="T_6a86f_row1_col17" class="data row1 col17" >nan</td>
#       <td id="T_6a86f_row1_col18" class="data row1 col18" >nan</td>
#       <td id="T_6a86f_row1_col19" class="data row1 col19" >137.000</td>
#       <td id="T_6a86f_row1_col20" class="data row1 col20" >2590.000</td>
#       <td id="T_6a86f_row1_col21" class="data row1 col21" >1546.000</td>
#       <td id="T_6a86f_row1_col22" class="data row1 col22" >1540.000</td>
#       <td id="T_6a86f_row1_col23" class="data row1 col23" >PETROL</td>
#       <t

# %%
df = co2.data.ml_preprocessing(df, countries=['FR', 'DE'],
                               elec_range_dummies=True,
                               rem_axlewidth=True,
                               rem_fuel_consumption=True,
                               rem_engine_capacity=True)
co2.styles.displayer(df)
# Out:
# /home/mln/GIT/car-co2-prediction_pre-release/src/auto_co2/data.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(name_dict, axis=1, inplace=True)
# Incomplete rows dropped:49817
# TOTAL NUMBER OF ROWS DROPPED:5661914
# <style type="text/css">
# #T_3d680 th {
#   background-color: steelblue;
#   color: white;
# }
# #T_3d680 tr:nth-of-type(odd) {
#   background-color: aliceblue;
# }
# #T_3d680 tr:nth-of-type(even) {
#   background-color: white;
# }
# </style>
# <table id="T_3d680">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d680_level0_col0" class="col_heading level0 col0" >MassRunningOrder</th>
#       <th id="T_3d680_level0_col1" class="col_heading level0 col1" >Co2EmissionsWltp</th>
#       <th id="T_3d680_level0_col2" class="col_heading level0 col2" >BaseWheel</th>
#       <th id="T_3d680_level0_col3" class="col_heading level0 col3" >FuelType</th>
#       <th id="T_3d680_level0_col4" class="col_heading level0 col4" >EnginePower</th>
#       <th id="T_3d680_level0_col5" class="col_heading level0 col5" >InnovativeTechnology</th>
#       <th id="T_3d680_level0_col6" class="col_heading level0 col6" >ElecRange_NO_RANGE</th>
#       <th id="T_3d680_level0_col7" class="col_heading level0 col7" >ElecRange_0to50</th>
#       <th id="T_3d680_level0_col8" class="col_heading level0 col8" >ElecRange_50to100</th>
#       <th id="T_3d680_level0_col9" class="col_heading level0 col9" >ElecRange_100to150</th>
#       <th id="T_3d680_level0_col10" class="col_heading level0 col10" >ElecRange_150+</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d680_level0_row0" class="row_heading level0 row0" >50000</th>
#       <td id="T_3d680_row0_col0" class="data row0 col0" >1598.000</td>
#       <td id="T_3d680_row0_col1" class="data row0 col1" >0.000</td>
#       <td id="T_3d680_row0_col2" class="data row0 col2" >2558.000</td>
#       <td id="T_3d680_row0_col3" class="data row0 col3" >ELECTRIC</td>
#       <td id="T_3d680_row0_col4" class="data row0 col4" >57.000</td>
#       <td id="T_3d680_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_3d680_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_3d680_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_3d680_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_3d680_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_3d680_row0_col10" class="data row0 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3d680_level0_row1" class="row_heading level0 row1" >50001</th>
#       <td id="T_3d680_row1_col0" class="data row1 col0" >1598.000</td>
#       <td id="T_3d680_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_3d680_row1_col2" class="data row1 col2" >2558.000</td>
#       <td id="T_3d680_row1_col3" class="data row1 col3" >ELECTRIC</td>
#       <td id="T_3d680_row1_col4" class="data row1 col4" >57.000</td>
#       <td id="T_3d680_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_3d680_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_3d680_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_3d680_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_3d680_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_3d680_row1_col10" class="data row1 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3d680_level0_row2" class="row_heading level0 row2" >50002</th>
#       <td id="T_3d680_row2_col0" class="data row2 col0" >1598.000</td>
#       <td id="T_3d680_row2_col1" class="data row2 col1" >0.000</td>
#       <td id="T_3d680_row2_col2" class="data row2 col2" >2558.000</td>
#       <td id="T_3d680_row2_col3" class="data row2 col3" >ELECTRIC</td>
#       <td id="T_3d680_row2_col4" class="data row2 col4" >57.000</td>
#       <td id="T_3d680_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_3d680_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_3d680_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_3d680_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_3d680_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_3d680_row2_col10" class="data row2 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3d680_level0_row3" class="row_heading level0 row3" >50003</th>
#       <td id="T_3d680_row3_col0" class="data row3 col0" >1598.000</td>
#       <td id="T_3d680_row3_col1" class="data row3 col1" >0.000</td>
#       <td id="T_3d680_row3_col2" class="data row3 col2" >2558.000</td>
#       <td id="T_3d680_row3_col3" class="data row3 col3" >ELECTRIC</td>
#       <td id="T_3d680_row3_col4" class="data row3 col4" >57.000</td>
#       <td id="T_3d680_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_3d680_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_3d680_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_3d680_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_3d680_row3_col9" class="data row3 col9" >0</td>
#       <td id="T_3d680_row3_col10" class="data row3 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3d680_level0_row4" class="row_heading level0 row4" >50004</th>
#       <td id="T_3d680_row4_col0" class="data row4 col0" >1598.000</td>
#       <td id="T_3d680_row4_col1" class="data row4 col1" >0.000</td>
#       <td id="T_3d680_row4_col2" class="data row4 col2" >2558.000</td>
#       <td id="T_3d680_row4_col3" class="data row4 col3" >ELECTRIC</td>
#       <td id="T_3d680_row4_col4" class="data row4 col4" >57.000</td>
#       <td id="T_3d680_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_3d680_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_3d680_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_3d680_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_3d680_row4_col9" class="data row4 col9" >0</td>
#       <td id="T_3d680_row4_col10" class="data row4 col10" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
co2.styles.display_describe(df )
# Out:
# <style type="text/css">
# #T_f7d78 th {
#   background-color: steelblue;
#   color: white;
# }
# #T_f7d78 tr:nth-of-type(odd) {
#   background-color: aliceblue;
# }
# #T_f7d78 tr:nth-of-type(even) {
#   background-color: white;
# }
# </style>
# <table id="T_f7d78">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7d78_level0_col0" class="col_heading level0 col0" >Colonne</th>
#       <th id="T_f7d78_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_f7d78_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_f7d78_level0_col3" class="col_heading level0 col3" >std</th>
#       <th id="T_f7d78_level0_col4" class="col_heading level0 col4" >min</th>
#       <th id="T_f7d78_level0_col5" class="col_heading level0 col5" >25%</th>
#       <th id="T_f7d78_level0_col6" class="col_heading level0 col6" >50%</th>
#       <th id="T_f7d78_level0_col7" class="col_heading level0 col7" >75%</th>
#       <th id="T_f7d78_level0_col8" class="col_heading level0 col8" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7d78_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f7d78_row0_col0" class="data row0 col0" >MassRunningOrder</td>
#       <td id="T_f7d78_row0_col1" class="data row0 col1" >4258194.000</td>
#       <td id="T_f7d78_row0_col2" class="data row0 col2" >1498.519</td>
#       <td id="T_f7d78_row0_col3" class="data row0 col3" >334.630</td>
#       <td id="T_f7d78_row0_col4" class="data row0 col4" >650.000</td>
#       <td id="T_f7d78_row0_col5" class="data row0 col5" >1254.000</td>
#       <td id="T_f7d78_row0_col6" class="data row0 col6" >1447.000</td>
#       <td id="T_f7d78_row0_col7" class="data row0 col7" >1695.000</td>
#       <td id="T_f7d78_row0_col8" class="data row0 col8" >3391.000</td>
#     </tr>
#     <tr>
#       <th id="T_f7d78_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f7d78_row1_col0" class="data row1 col0" >Co2EmissionsWltp</td>
#       <td id="T_f7d78_row1_col1" class="data row1 col1" >4258194.000</td>
#       <td id="T_f7d78_row1_col2" class="data row1 col2" >112.430</td>
#       <td id="T_f7d78_row1_col3" class="data row1 col3" >58.007</td>
#       <td id="T_f7d78_row1_col4" class="data row1 col4" >0.000</td>
#       <td id="T_f7d78_row1_col5" class="data row1 col5" >106.000</td>
#       <td id="T_f7d78_row1_col6" class="data row1 col6" >125.000</td>
#       <td id="T_f7d78_row1_col7" class="data row1 col7" >143.000</td>
#       <td id="T_f7d78_row1_col8" class="data row1 col8" >572.000</td>
#     </tr>
#     <tr>
#       <th id="T_f7d78_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f7d78_row2_col0" class="data row2 col0" >BaseWheel</td>
#       <td id="T_f7d78_row2_col1" class="data row2 col1" >4258194.000</td>
#       <td id="T_f7d78_row2_col2" class="data row2 col2" >2664.093</td>
#       <td id="T_f7d78_row2_col3" class="data row2 col3" >169.344</td>
#       <td id="T_f7d78_row2_col4" class="data row2 col4" >1296.000</td>
#       <td id="T_f7d78_row2_col5" class="data row2 col5" >2570.000</td>
#       <td id="T_f7d78_row2_col6" class="data row2 col6" >2650.000</td>
#       <td id="T_f7d78_row2_col7" class="data row2 col7" >2730.000</td>
#       <td id="T_f7d78_row2_col8" class="data row2 col8" >4490.000</td>
#     </tr>
#     <tr>
#       <th id="T_f7d78_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f7d78_row3_col0" class="data row3 col0" >EnginePower</td>
#       <td id="T_f7d78_row3_col1" class="data row3 col1" >4258194.000</td>
#       <td id="T_f7d78_row3_col2" class="data row3 col2" >103.689</td>
#       <td id="T_f7d78_row3_col3" class="data row3 col3" >52.153</td>
#       <td id="T_f7d78_row3_col4" class="data row3 col4" >18.000</td>
#       <td id="T_f7d78_row3_col5" class="data row3 col5" >70.000</td>
#       <td id="T_f7d78_row3_col6" class="data row3 col6" >96.000</td>
#       <td id="T_f7d78_row3_col7" class="data row3 col7" >115.000</td>
#       <td id="T_f7d78_row3_col8" class="data row3 col8" >1177.000</td>
#     </tr>
#     <tr>
#       <th id="T_f7d78_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f7d78_row4_col0" class="data row4 col0" >InnovativeTechnology</td>
#       <td id="T_f7d78_row4_col1" class="data row4 col1" >4258194.000</td>
#       <td id="T_f7d78_row4_col2" class="data row4 col2" >0.537</td>
#       <td id="T_f7d78_row4_col3" class="data row4 col3" >0.499</td>
#       <td id="T_f7d78_row4_col4" class="data row4 col4" >0.000</td>
#       <td id="T_f7d78_row4_col5" class="data row4 col5" >0.000</td>
#       <td id="T_f7d78_row4_col6" class="data row4 col6" >1.000</td>
#       <td id="T_f7d78_row4_col7" class="data row4 col7" >1.000</td>
#       <td id="T_f7d78_row4_col8" class="data row4 col8" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_f7d78_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f7d78_row5_col0" class="data row5 col0" >ElecRange_NO_RANGE</td>
#       <td id="T_f7d78_row5_col1" class="data row5 col1" >4258194.000</td>
#       <td id="T_f7d78_row5_col2" class="data row5 col2" >0.849</td>
#       <td id="T_f7d78_row5_col3" class="data row5 col3" >0.358</td>
#       <td id="T_f7d78_row5_col4" class="data row5 col4" >0.000</td>
#       <td id="T_f7d78_row5_col5" class="data row5 col5" >1.000</td>
#       <td id="T_f7d78_row5_col6" class="data row5 col6" >1.000</td>
#       <td id="T_f7d78_row5_col7" class="data row5 col7" >1.000</td>
#       <td id="T_f7d78_row5_col8" class="data row5 col8" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_f7d78_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f7d78_row6_col0" class="data row6 col0" >ElecRange_0to50</td>
#       <td id="T_f7d78_row6_col1" class="data row6 col1" >4258194.000</td>
#       <td id="T_f7d78_row6_col2" class="data row6 col2" >0.020</td>
#       <td id="T_f7d78_row6_col3" class="data row6 col3" >0.141</td>
#       <td id="T_f7d78_row6_col4" class="data row6 col4" >0.000</td>
#       <td id="T_f7d78_row6_col5" class="data row6 col5" >0.000</td>
#       <td id="T_f7d78_row6_col6" class="data row6 col6" >0.000</td>
#       <td id="T_f7d78_row6_col7" class="data row6 col7" >0.000</td>
#       <td id="T_f7d78_row6_col8" class="data row6 col8" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_f7d78_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f7d78_row7_col0" class="data row7 col0" >ElecRange_50to100</td>
#       <td id="T_f7d78_row7_col1" class="data row7 col1" >4258194.000</td>
#       <td id="T_f7d78_row7_col2" class="data row7 col2" >0.074</td>
#       <td id="T_f7d78_row7_col3" class="data row7 col3" >0.261</td>
#       <td id="T_f7d78_row7_col4" class="data row7 col4" >0.000</td>
#       <td id="T_f7d78_row7_col5" class="data row7 col5" >0.000</td>
#       <td id="T_f7d78_row7_col6" class="data row7 col6" >0.000</td>
#       <td id="T_f7d78_row7_col7" class="data row7 col7" >0.000</td>
#       <td id="T_f7d78_row7_col8" class="data row7 col8" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_f7d78_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f7d78_row8_col0" class="data row8 col0" >ElecRange_100to150</td>
#       <td id="T_f7d78_row8_col1" class="data row8 col1" >4258194.000</td>
#       <td id="T_f7d78_row8_col2" class="data row8 col2" >0.004</td>
#       <td id="T_f7d78_row8_col3" class="data row8 col3" >0.060</td>
#       <td id="T_f7d78_row8_col4" class="data row8 col4" >0.000</td>
#       <td id="T_f7d78_row8_col5" class="data row8 col5" >0.000</td>
#       <td id="T_f7d78_row8_col6" class="data row8 col6" >0.000</td>
#       <td id="T_f7d78_row8_col7" class="data row8 col7" >0.000</td>
#       <td id="T_f7d78_row8_col8" class="data row8 col8" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_f7d78_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f7d78_row9_col0" class="data row9 col0" >ElecRange_150+</td>
#       <td id="T_f7d78_row9_col1" class="data row9 col1" >4258194.000</td>
#       <td id="T_f7d78_row9_col2" class="data row9 col2" >0.016</td>
#       <td id="T_f7d78_row9_col3" class="data row9 col3" >0.125</td>
#       <td id="T_f7d78_row9_co

# %%
co2.data.save_processed_data(df, classification=True, pickle=True, filepath='data/processed/')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 co2.data.save_processed_data(df, classification=True, pickle=True, filepath='data/processed/')
#
# File ~/GIT/car-co2-prediction_pre-release/src/auto_co2/data.py:237, in save_processed_data(df, classification, pickle, filepath)
#     235     filename = 'co2_regression_{timestamp}'
#     236 if pickle:
# --> 237     df.to_pickle(f"{filepath}/{filename.split('.')[0]}.pkl")
#     238 df.to_csv(f'{filepath}/{filename}.csv', index=False)
#     239 print(f"Data saved to {filepath}/{filename}")
#
# File ~/miniconda3/envs/co2/lib/python3.9/site-packages/pandas/core/generic.py:3085, in NDFrame.to_pickle(self, path, compression, protocol, storage_options)
#    3033 """
#    3034 Pickle (serialize) object to file.
#    3035
#    (...)
#    3081 4    4    9
#    3082 """  # noqa: E501
#    3083 from pandas.io.pickle import to_pickle
# -> 3085 to_pickle(
#    3086     self,
#    3087     path,
#    3088     compression=compression,
#    3089     protocol=protocol,
#    3090     storage_options=storage_options,
#    3091 )
#
# File ~/miniconda3/envs/co2/lib/python3.9/site-packages/pandas/io/pickle.py:105, in to_pickle(obj, filepath_or_buffer, compression, protocol, storage_options)
#     102 if protocol < 0:
#     103     protocol = pickle.HIGHEST_PROTOCOL
# --> 105 with get_handle(
#     106     filepath_or_buffer,
#     107     "wb",
#     108     compression=compression,
#     109     is_text=False,
#     110     storage_options=storage_options,
#     111 ) as handles:
#     112     # letting pickle write directly to the buffer is more memory-efficient
#     113     pickle.dump(obj, handles.handle, protocol=protocol)
#
# File ~/miniconda3/envs/co2/lib/python3.9/site-packages/pandas/io/common.py:739, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     737 # Only for write methods
#     738 if "r" not in mode and is_path:
# --> 739     check_parent_directory(str(handle))
#     741 if compression:
#     742     if compression != "zstd":
#     743         # compression libraries do not like an explicit text-mode
#
# File ~/miniconda3/envs/co2/lib/python3.9/site-packages/pandas/io/common.py:604, in check_parent_directory(path)
#     602 parent = Path(path).parent
#     603 if not parent.is_dir():
# --> 604     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'data/processed'
